# %% [markdown]
# <a href="https://colab.research.google.com/github/BenMeehan/Foundational_Machine_Learning/blob/main/Random_Forests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("WineQT.csv")

# %%
y=np.array(df["quality"])

# %%
df=df.drop(["Id","quality"],axis=1)

# %%
x=np.array(df)

# %%
t=DecisionTreeClassifier(random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y)

# %%
t.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
ypred=t.predict(xtest)

# %%
print(t.score(xtest,ytest))
print(t.score(xtrain,ytrain))
# Out:
# 0.5804195804195804
# 1.0

# %%
from sklearn import tree

# %%
tree.plot_tree(t)
# Out:
# [Text(0.42882796358471076, 0.9705882352941176, 'X[10] <= 9.85\ngini = 0.645\nsamples = 857\nvalue = [6, 25, 360, 343, 111, 12]'),
#  Text(0.18181818181818182, 0.9117647058823529, 'X[9] <= 0.575\ngini = 0.463\nsamples = 325\nvalue = [3, 9, 221, 88, 3, 1]'),
#  Text(0.08122417355371901, 0.8529411764705882, 'X[8] <= 3.54\ngini = 0.335\nsamples = 136\nvalue = [2, 4, 109, 20, 1, 0]'),
#  Text(0.07709194214876033, 0.7941176470588235, 'X[10] <= 9.75\ngini = 0.319\nsamples = 134\nvalue = [2, 4, 109, 18, 1, 0]'),
#  Text(0.0446797520661157, 0.7352941176470589, 'X[10] <= 9.05\ngini = 0.282\nsamples = 119\nvalue = [2, 4, 100, 12, 1, 0]'),
#  Text(0.022727272727272728, 0.6764705882352942, 'X[3] <= 2.25\ngini = 0.722\nsamples = 6\nvalue = [1, 1, 2, 2, 0, 0]'),
#  Text(0.01859504132231405, 0.6176470588235294, 'X[1] <= 0.6\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 2, 0, 0, 0]'),
#  Text(0.014462809917355372, 0.5588235294117647, 'X[8] <= 3.31\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(random_state=42)

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print(rf.predict(xtest))
# Out:
# [6 5 6 6 6 5 5 5 5 5 5 5 5 6 5 5 5 6 6 7 5 5 7 6 7 5 5 5 6 6 6 5 7 7 6 6 5
#  5 5 7 5 7 6 5 6 6 6 6 5 5 6 5 8 7 6 6 5 5 5 7 5 5 5 6 6 5 5 6 6 5 6 6 7 6
#  6 6 6 6 5 5 6 6 7 6 6 5 5 5 5 5 5 7 6 5 5 5 5 6 5 6 5 5 5 5 5 6 6 5 5 6 6
#  5 5 5 5 6 5 5 6 5 6 7 6 6 5 6 6 5 7 5 5 7 6 5 5 6 5 5 5 5 5 5 5 5 5 6 5 6
#  6 7 6 6 6 5 6 5 5 6 6 5 5 7 5 5 5 6 5 5 6 6 6 5 5 5 5 6 6 5 5 5 6 5 6 5 5
#  5 5 5 7 5 6 6 6 5 5 5 6 6 5 6 5 6 7 6 6 5 6 7 5 7 5 6 5 6 6 5 5 6 6 6 7 6
#  5 5 6 6 5 5 5 5 6 6 6 6 5 5 6 5 5 5 6 6 6 5 5 7 5 6 5 6 6 6 7 6 6 5 5 6 6
#  6 6 5 6 7 6 5 6 5 7 7 7 5 5 5 5 5 6 6 6 5 7 6 6 6 7 5]

# %%
print(rf.score(xtest,ytest))
print(rf.score(xtrain,ytrain))
# Out:
# 0.6503496503496503
# 1.0
